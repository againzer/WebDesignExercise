# %%
import pandas as pd
from IPython.display import HTML

# %%
filepath = "Resources/weather_df.csv"
file = pd.read_csv(filepath)
file = file.drop("Unnamed: 0",axis=1)
df = pd.DataFrame(file)
df
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Punta Arenas -53.1500  -70.9167     50.00        87          75
# 1       Busselton -33.6500  115.3333     57.99        79         100
# 2           Bluff -46.6000  168.3333     48.00        96          94
# 3         Aksarka  66.5606   67.7975     36.90        90         100
# 4          Castro -24.7911  -50.0119     63.70        71          85
# ..            ...      ...       ...       ...       ...         ...
# 540       Paciran  -6.8767  112.3761     77.47        77          73
# 541          Tual  -5.6667  132.7500     83.80        72          85
# 542      Challans  46.8436   -1.8749     68.00        42           0
# 543          Auki  -8.7676  160.7034     77.18        85          97
# 544     Marystown  47.1666  -55.1483     42.60        96         100
#
#      Wind Speed Country        Date
# 0          8.05      CL  1619113847
# 1          1.01      AU  1619113847
# ...

# %%
result = df.to_html()
print(result)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Punta Arenas</td>
#       <td>-53.1500</td>
#       <td>-70.9167</td>
#       <td>50.00</td>
#       <td>87</td>
#       <td>75</td>
#       <td>8.05</td>
#       <td>CL</td>
#       <td>1619113847</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Busselton</td>
#       <td>-33.6500</td>
#       <td>115.3333</td>
#       <td>57.99</td>
#       <td>79</td>
#       <td>100</td>
#       <td>1.01</td>
#       <td>AU</td>
#       <td>1619113847</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Bluff</td>
#       <td>-46.6000</td>
#       <td>168.3333</td>
# ...
